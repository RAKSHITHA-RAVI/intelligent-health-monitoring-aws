# %%
import boto3, io, pandas as pd
from sklearn.model_selection import train_test_split
import sagemaker
from sagemaker import get_execution_role

region = "us-east-1" # update if needed
bucket = "healthcare-project-data-rakshitha" # your bucket name
role = get_execution_role()
s3 = boto3.client("s3", region_name=region)

hist_key = "raw/historical/heart_attack_prediction_dataset.csv"
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
#load the processed/merged CSV from S3 (produced by EMR) to confirm shape & columns.

obj = s3.get_object(Bucket=bucket, Key=hist_key)
df = pd.read_csv(io.BytesIO(obj["Body"].read()))
print("Loaded dataset:", df.shape)
df.head(2)
# Out:
# Loaded dataset: (8763, 26)
#   Patient ID  Age   Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67  Male          208         158/88          72         0
# 1    CZE1114   21  Male          389         165/93          98         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# 0  31.251233            286                                0
# 1  27.194973            235                                1
#
#    Sleep Hours Per Day    Country      Continent           Hemisphere  \
# 0                    6  Argentina  South America  Southern Hemisphere
# 1                    7     Canada  North America  Northern Hemisphere
#
#    Heart Attack Risk
# 0                  0
# 1                  0
#
# [2 rows x 26 columns]

# %%
def preprocess_health_data(df):
    # Split blood pressure
    if "Blood Pressure" in df.columns:
        bp = df["Blood Pressure"].astype(str).str.split("/", n=1, expand=True)
        df["BP_Systolic"] = pd.to_numeric(bp[0], errors="coerce")
        df["BP_Diastolic"] = pd.to_numeric(bp[1], errors="coerce")
        df.drop(columns=["Blood Pressure"], inplace=True)

    # Drop identifiers
    df = df.drop(columns=["Patient ID","Country","Continent","Hemisphere"], errors="ignore")

    # One-hot encode categoricals
    df = pd.get_dummies(df, drop_first=True).fillna(0)
    return df

# %%
proc_df = preprocess_health_data(df)
y = proc_df["Heart Attack Risk"].astype(int)
X = proc_df.drop(columns=["Heart Attack Risk"])
final_df = pd.concat([y, X], axis=1)
train_df, test_df = train_test_split(final_df, test_size=0.2, random_state=42, stratify=y)
print("Train:", train_df.shape, "| Test:", test_df.shape)
print("\n Sample training row:")
display(train_df.head(1))
# Out:
# Train: (7010, 24) | Test: (1753, 24)
#
#  Sample training row:
#       Heart Attack Risk  Age  Cholesterol  Heart Rate  Diabetes  \
# 1034                  0   21          250          78         1
#
#       Family History  Smoking  Obesity  Alcohol Consumption  \
# 1034               0        1        0                    1
#
#       Exercise Hours Per Week  ...  Income        BMI  Triglycerides  \
# 1034                 2.392506  ...  273208  23.575795            176
#
#       Physical Activity Days Per Week  Sleep Hours Per Day  BP_Systolic  \
# 1034                                2                    5          109
#
#       BP_Diastolic  Sex_Male  Diet_Healthy  Diet_Unhealthy
# 1034            76      True          True           False
#
# [1 rows x 24 columns]

# %%
train_key = "raw/historical/train/train.csv"
test_key = "raw/historical/test/test.csv"

def upload_csv(df, key):
    s3.put_object(Bucket=bucket, Key=key, Body=df.to_csv(index=False, header=False).encode())
    print(f"Uploaded → s3://{bucket}/{key}")

upload_csv(train_df, train_key)
upload_csv(test_df, test_key)
# Out:
# Uploaded → s3://healthcare-project-data-rakshitha/raw/historical/train/train.csv
# Uploaded → s3://healthcare-project-data-rakshitha/raw/historical/test/test.csv

# %%
feature_list = list(X.columns)
with open("feature_list.txt", "w") as f:
    f.write("\n".join(feature_list))

# !aws s3 cp feature_list.txt s3://{bucket}/preprocess/feature_list.txt
print(f" Uploaded feature list → s3://{bucket}/preprocess/feature_list.txt")
# Out:
# upload: ./feature_list.txt to s3://healthcare-project-data-rakshitha/preprocess/feature_list.txt
#  Uploaded feature list → s3://healthcare-project-data-rakshitha/preprocess/feature_list.txt

# %%
from sagemaker.estimator import Estimator
from sagemaker.inputs import TrainingInput
import time

timestamp = time.strftime("%Y-%m-%d-%H-%M-%S")
output_path = f"s3://{bucket}/models/xgboost"
xgb_image = sagemaker.image_uris.retrieve("xgboost", region=region, version="1.5-1")

xgb_estimator = Estimator(
    image_uri=xgb_image,
    role=role,
    instance_count=1,
    instance_type="ml.m5.large",
    volume_size=5,
    output_path=output_path,
    base_job_name=f"xgboost-heart-attack-{timestamp}",
)

xgb_estimator.set_hyperparameters(
    objective="binary:logistic",
    num_round=100,
    eta=0.1,
    max_depth=5,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="auc"
)

train_input = f"s3://{bucket}/{train_key}"
test_input = f"s3://{bucket}/{test_key}"

print(" Starting training job.")
xgb_estimator.fit(
    {
        "train": TrainingInput(train_input, content_type="text/csv"),
        "validation": TrainingInput(test_input, content_type="text/csv")
    }
)

model_artifact = xgb_estimator.model_data
print(" Model training complete!")
print(" Model artifact stored at:", model_artifact)
# Out:
# INFO:sagemaker:Creating training-job with name: xgboost-heart-attack-2025-11-18-20-00-1-2025-11-18-20-00-17-594
#  Starting training job.
# 2025-11-18 20:00:17 Starting - Starting the training job...
# 2025-11-18 20:00:43 Starting - Preparing the instances for training...
# 2025-11-18 20:01:10 Downloading - Downloading input data...
# 2025-11-18 20:01:45 Downloading - Downloading the training image......
# 2025-11-18 20:02:46 Training - Training image download completed. Training in progress../miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2025-11-18 20:02:48.525 ip-10-2-65-54.ec2.internal:8 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-11-18 20:02:48.547 ip-10-2-65-54.ec2.internal:8 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-11-18:20:02:48:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-11-18:20:02:48:INFO] Failed to parse hyperparameter eval_metric value auc to Json.
# Returning the value itself
# [2025-11-18:20:02:48:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2025-11-18:20:02:48:INFO] No GPUs detected (normal if no gpus installed)
# [2025-11-18:20:02:48:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-11-18:20:02:48:INFO] Determined 0 GPU(s) available on the instance.
# [2025-11-18:20:02:48:INFO] Determined delimiter of CSV input is ','
# [2025-11-18:20:02:48:INFO] Determined delimiter of CSV input is ','
# [2025-11-18:20:02:48:INFO] files path: /opt/ml/input/data/train
# [2025-11-18:20:02:48:INFO] Determined delimiter of CSV input is ','
# [2025-11-18:20:02:48:INFO] files path: /opt/ml/input/data/validation
# [2025-11-18:20:02:48:INFO] Determined delimiter of CSV input is ','
# [2025-11-18:20:02:48:INFO] Single node training.
# [2025-11-18:20:02:48:INFO] Train matrix has 7010 rows and 23 columns
# [2025-11-18:20:02:48:INFO] Validation matrix has 1753 rows
# [2025-11-18 20:02:48.954 ip-10-2-65-54.ec2.internal:8 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-11-18 20:02:48.955 ip-10-2-65-54.ec2.internal:8 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-11-18 20:02:48.955 ip-10-2-65-54.ec2.internal:8 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2025-11-18 20:02:48.955 ip-10-2-65-54.ec2.internal:8 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-11-18:20:02:48:INFO] Debug hook created from config
# [2025-11-18 20:02:48.986 ip-10-2-65-54.ec2.internal:8 INFO hook.py:427] Monitoring the collections: metrics
# [2025-11-18 20:02:48.988 ip-10-2-65-54.ec2.internal:8 INFO hook.py:491] Hook is writing from the hook with pid: 8
# [0]#011train-auc:0.56507#011validation-auc:0.50455
# [1]#011train-auc:0.60595#011validation-auc:0.51776
# [2]#011train-auc:0.62782#011validation-auc:0.51556
# [3]#011train-auc:0.63923#011validation-auc:0.51271
# [4]#011train-auc:0.65964#011validation-auc:0.51202
# [5]#011train-auc:0.67257#011validation-auc:0.50837
# [6]#011train-auc:0.68202#011validation-auc:0.51744
# [7]#011train-auc:0.68051#011validation-auc:0.51544
# [8]#011train-auc:0.68701#011validation-auc:0.50785
# [9]#011train-auc:0.69327#011validation-auc:0.50322
# [10]#011train-auc:0.70723#011validation-auc:0.50831
# [11]#011train-auc:0.71827#011validation-auc:0.50642
# [12]#011train-auc:0.72072#011validation-auc:0.51279
# [13]#011train-auc:0.72538#011validation-auc:0.51270
# [14]#011train-auc:0.72655#011validation-auc:0.51006
# [15]#011train-auc:0.73069#011validation-auc:0.51180
# [16]#011train-auc:0.73531#011validation-auc:0.51386
# [17]#011train-auc:0.74573#011validation-auc:0.51861
# [18]#011train-auc:0.74657#011validation-auc:0.51717
# [19]#011train-auc:0.74970#011validation-auc:0.51540
# [20]#011train-auc:0.75437#011validation-auc:0.51212
# [21]#011train-auc:0.75970#011validation-auc:0.50705
# [22]#011train-auc:0.76701#011validation-auc:0.50446
# [23]#011train-auc:0.76709#011validation-auc:0.50343
# [24]#011train-auc:0.77099#011validation-auc:0.50841
# [25]#011train-auc:0.77375#011validation-auc:0.51139
# [26]#011train-auc:0.77510#011validation-auc:0.50863
# [27]#011train-auc:0.78089#011validation-auc:0.51253
# [28]#011train-auc:0.78345#011validation-auc:0.51581
# [29]#011train-auc:0.78954#011validation-auc:0.51508
# [30]#011train-auc:0.79319#011validation-auc:0.52059
# [31]#011train-auc:0.79523#011validation-auc:0.52071
# [32]#011train-auc:0.80155#011validation-auc:0.51803
# [33]#011train-auc:0.80300#011validation-auc:0.51631
# [34]#011train-auc:0.80611#011validation-auc:0.51332
# [35]#011train-auc:0.80540#011validation-auc:0.51395
# [36]#011train-auc:0.80908#011validation-auc:0.51042
# [37]#011train-auc:0.81271#011validation-auc:0.51338
# [38]#011train-auc:0.81693#011validation-auc:0.51628
# [39]#011train-auc:0.81992#011validation-auc:0.51549
# [40]#011train-auc:0.82345#011validation-auc:0.51882
# [41]#011train-auc:0.82498#011validation-auc:0.51727
# [42]#011train-auc:0.82517#011validation-auc:0.51776
# [43]#011train-auc:0.83100#011validation-auc:0.51825
# [44]#011train-auc:0.83462#011validation-auc:0.51932
# [45]#011train-auc:0.83728#011validation-auc:0.52125
# [46]#011train-auc:0.84078#011validation-auc:0.52132
# [47]#011train-auc:0.84447#011validation-auc:0.52268
# [48]#011train-auc:0.84755#011validation-auc:0.52415
# [49]#011train-auc:0.84817#011validation-auc:0.52471
# [50]#011train-auc:0.85230#011validation-auc:0.52478
# [51]#011train-auc:0.85223#011validation-auc:0.52325
# [52]#011train-auc:0.85307#011validation-auc:0.52160
# [53]#011train-auc:0.85489#011validation-auc:0.52197
# [54]#011train-auc:0.85738#011validation-auc:0.52319
# [55]#011train-auc:0.85838#011validation-auc:0.52520
# [56]#011train-auc:0.85979#011validation-auc:0.52444
# [57]#011train-auc:0.86173#011validation-auc:0.52881
# [58]#011train-auc:0.86507#011validation-auc:0.53176
# [59]#011train-auc:0.86634#011validation-auc:0.53128
# [60]#011train-auc:0.86819#011validation-auc:0.52657
# [61]#011train-auc:0.86972#011validation-auc:0.52709
# [62]#011train-auc:0.87091#011validation-auc:0.52679
# [63]#011train-auc:0.87137#011validation-auc:0.52539
# [64]#011train-auc:0.87269#011validation-auc:0.52353
# [65]#011train-auc:0.87558#011validation-auc:0.52152
# [66]#011train-auc:0.87686#011validation-auc:0.52236
# [67]#011train-auc:0.87953#011validation-auc:0.52264
# [68]#011train-auc:0.88260#011validation-auc:0.52432
# [69]#011train-auc:0.88477#011validation-auc:0.52216
# [70]#011train-auc:0.88668#011validation-auc:0.52129
# [71]#011train-auc:0.88839#011validation-auc:0.52166
# [72]#011train-auc:0.89025#011validation-auc:0.52206
# [73]#011train-auc:0.89210#011validation-auc:0.52226
# [74]#011train-auc:0.89403#011validation-auc:0.52188
# [75]#011train-auc:0.89611#011validation-auc:0.52089
# [76]#011train-auc:0.89694#011validation-auc:0.52133
# [77]#011train-auc:0.89939#011validation-auc:0.52055
# [78]#011train-auc:0.90050#011validation-auc:0.52012
# [79]#011train-auc:0.90317#011validation-auc:0.51855
# [80]#011train-auc:0.90336#011validation-auc:0.51832
# [81]#011train-auc:0.90449#011validation-auc:0.51946
# [82]#011train-auc:0.90546#011validation-auc:0.52044
# [83]#011train-auc:0.90702#011validation-auc:0.52249
# [84]#011train-auc:0.90725#011validation-auc:0.52185
# [85]#011train-auc:0.90906#011validation-auc:0.52334
# [86]#011train-auc:0.90926#011validation-auc:0.52377
# [87]#011train-auc:0.91035#011validation-auc:0.52411
# [88]#011train-auc:0.91132#011validation-auc:0.52333
# [89]#011train-auc:0.91122#011validation-auc:0.52206
# [90]#011train-auc:0.91321#011validation-auc:0.52336
# [91]#011train-auc:0.91507#011validation-auc:0.52409
# [92]#011train-auc:0.91607#011validation-auc:0.52393
# [93]#011train-auc:0.91741#011validation-auc:0.52436
# [94]#011train-auc:0.91862#011validation-auc:0.52424
# [95]#011train-auc:0.91901#011validation-auc:0.52497
# [96]#011train-auc:0.92023#011validation-auc:0.52498
# [97]#011train-auc:0.92087#011validation-auc:0.52441
# [98]#011train-auc:0.92166#011validation-auc:0.52274
# [99]#011train-auc:0.92220#011validation-auc:0.52174
#
# 2025-11-18 20:03:09 Uploading - Uploading generated training model
# 2025-11-18 20:03:09 Completed - Training job completed
# Training seconds: 120
# Billable seconds: 120
#  Model training complete!
#  Model artifact stored at: s3://healthcare-project-data-rakshitha/models/xgboost/xgboost-heart-attack-2025-11-18-20-00-1-2025-11-18-20-00-17-594/output/model.tar.gz

# %%
from sagemaker.model import Model
import sagemaker, time

sagemaker_session = sagemaker.session.Session()
timestamp = time.strftime("%Y-%m-%d-%H-%M-%S")
xgb_image = sagemaker.image_uris.retrieve("xgboost", region=region, version="1.5-1")

# Define the model object
xgb_model = Model(
    image_uri=xgb_image,
    model_data=model_artifact,
    role=role,
    name=f"xgb-heart-attack-{timestamp}",
    sagemaker_session=sagemaker_session,
)

# Create a custom endpoint name
endpoint_name = f"xgb-heart-attack-endpoint-{timestamp}"
print(f" Deploying XGBoost model as endpoint: {endpoint_name} .")

# Deploy using the model's .deploy() — returns None in newer SDKs,
# so we attach a Predictor manually afterward
xgb_model.deploy(
    initial_instance_count=1,
    instance_type="ml.m5.large",
    endpoint_name=endpoint_name
)

# Manually create predictor for runtime access
from sagemaker.predictor import Predictor
predictor = Predictor(endpoint_name=endpoint_name, sagemaker_session=sagemaker_session)

print("\n Model deployed successfully!")
print(" Endpoint name:", endpoint_name)
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating model with name: xgb-heart-attack-2025-11-18-20-06-53
#  Deploying XGBoost model as endpoint: xgb-heart-attack-endpoint-2025-11-18-20-06-53 .
# INFO:sagemaker:Creating endpoint-config with name xgb-heart-attack-endpoint-2025-11-18-20-06-53
# INFO:sagemaker:Creating endpoint with name xgb-heart-attack-endpoint-2025-11-18-20-06-53
# -------!
#  Model deployed successfully!
#  Endpoint name: xgb-heart-attack-endpoint-2025-11-18-20-06-53
